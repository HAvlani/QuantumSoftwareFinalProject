# %%
import qiskit
from qiskit import QuantumCircuit, QuantumRegister
from random import seed
from random import random
import numpy as np
import h5py
import cmath

# %%
num_qubit = 10
depth = 9
register = QuantumRegister(num_qubit)
circuit = QuantumCircuit(register)
for i in range(num_qubit):
    circuit.rx(random(), register)
    circuit.rz(random(), register)
    circuit.rx(random(), register)
    cx_counter = 0
    while cx_counter <= len(register) - 1:
        circuit.cx(register[cx_counter], register[cx_counter + 1])
        cx_counter += 2
    cx_counter = 1
    while cx_counter <= len(register) - 2:
        circuit.cx(register[cx_counter], register[cx_counter + 1])
        cx_counter += 2
    #circuit.barrier(register)
print(circuit)
# Out:
#       ┌─────────────┐┌─────────────┐┌─────────────┐     ┌─────────────┐»
# q2_0: ┤ Rx(0.78447) ├┤ Rz(0.86697) ├┤ Rx(0.94779) ├──■──┤ Rx(0.10097) ├»
#       ├─────────────┤├─────────────┤├─────────────┤┌─┴─┐└─────────────┘»
# q2_1: ┤ Rx(0.78447) ├┤ Rz(0.86697) ├┤ Rx(0.94779) ├┤ X ├───────■───────»
#       ├─────────────┤├─────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# q2_2: ┤ Rx(0.78447) ├┤ Rz(0.86697) ├┤ Rx(0.94779) ├──■───────┤ X ├─────»
#       ├─────────────┤├─────────────┤├─────────────┤┌─┴─┐     └───┘     »
# q2_3: ┤ Rx(0.78447) ├┤ Rz(0.86697) ├┤ Rx(0.94779) ├┤ X ├───────■───────»
#       ├─────────────┤├─────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# q2_4: ┤ Rx(0.78447) ├┤ Rz(0.86697) ├┤ Rx(0.94779) ├──■───────┤ X ├─────»
#       ├─────────────┤├─────────────┤├─────────────┤┌─┴─┐     └───┘     »
# q2_5: ┤ Rx(0.78447) ├┤ Rz(0.86697) ├┤ Rx(0.94779) ├┤ X ├───────■───────»
#       ├─────────────┤├─────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# q2_6: ┤ Rx(0.78447) ├┤ Rz(0.86697) ├┤ Rx(0.94779) ├──■───────┤ X ├─────»
#       ├─────────────┤├─────────────┤├─────────────┤┌─┴─┐     └───┘     »
# q2_7: ┤ Rx(0.78447) ├┤ Rz(0.86697) ├┤ Rx(0.94779) ├┤ X ├───────■───────»
#       ├─────────────┤├─────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# q2_8: ┤ Rx(0.78447) ├┤ Rz(0.86697) ├┤ Rx(0.94779) ├──■───────┤ X ├─────»
#       ├─────────────┤├─────────────┤├─────────────┤┌─┴─┐┌────┴───┴────┐»
# q2_9: ┤ Rx(0.78447) ├┤ Rz(0.86697) ├┤ Rx(0.94779) ├┤ X ├┤ Rx(0.10097) ├»
#       └─────────────┘└─────────────┘└─────────────┘└───┘└─────────────┘»
# «       ┌────────────┐┌─────────────┐                    ┌─────────────┐»
# «q2_0: ─┤ Rz(0.8779) ├┤ Rx(0.68088) ├─────────────────■──┤ Rx(0.23822) ├»
# «      ┌┴────────────┤└┬────────────┤┌─────────────┐┌─┴─┐└─────────────┘»
# «q2_1: ┤ Rx(0.10097) ├─┤ Rz(0.8779) ├┤ Rx(0.68088) ├┤ X ├───────■───────»
# «      ├─────────────┤ ├────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_2: ┤ Rx(0.10097) ├─┤ Rz(0.8779) ├┤ Rx(0.68088) ├──■───────┤ X ├─────»
# «      ├─────────────┤ ├────────────┤├─────────────┤┌─┴─┐     └───┘     »
# «q2_3: ┤ Rx(0.10097) ├─┤ Rz(0.8779) ├┤ Rx(0.68088) ├┤ X ├───────■───────»
# «      ├─────────────┤ ├────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_4: ┤ Rx(0.10097) ├─┤ Rz(0.8779) ├┤ Rx(0.68088) ├──■───────┤ X ├─────»
# «      ├─────────────┤ ├────────────┤├─────────────┤┌─┴─┐     └───┘     »
# «q2_5: ┤ Rx(0.10097) ├─┤ Rz(0.8779) ├┤ Rx(0.68088) ├┤ X ├───────■───────»
# «      ├─────────────┤ ├────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_6: ┤ Rx(0.10097) ├─┤ Rz(0.8779) ├┤ Rx(0.68088) ├──■───────┤ X ├─────»
# «      ├─────────────┤ ├────────────┤├─────────────┤┌─┴─┐     └───┘     »
# «q2_7: ┤ Rx(0.10097) ├─┤ Rz(0.8779) ├┤ Rx(0.68088) ├┤ X ├───────■───────»
# «      ├─────────────┤ ├────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_8: ┤ Rx(0.10097) ├─┤ Rz(0.8779) ├┤ Rx(0.68088) ├──■───────┤ X ├─────»
# «      └┬────────────┤┌┴────────────┤└─────────────┘┌─┴─┐┌────┴───┴────┐»
# «q2_9: ─┤ Rz(0.8779) ├┤ Rx(0.68088) ├───────────────┤ X ├┤ Rx(0.23822) ├»
# «       └────────────┘└─────────────┘               └───┘└─────────────┘»
# «      ┌─────────────┐┌─────────────┐                    ┌─────────────┐»
# «q2_0: ┤ Rz(0.66115) ├┤ Rx(0.50618) ├─────────────────■──┤ Rx(0.54273) ├»
# «      ├─────────────┤├─────────────┤┌─────────────┐┌─┴─┐└─────────────┘»
# «q2_1: ┤ Rx(0.23822) ├┤ Rz(0.66115) ├┤ Rx(0.50618) ├┤ X ├───────■───────»
# «      ├─────────────┤├─────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_2: ┤ Rx(0.23822) ├┤ Rz(0.66115) ├┤ Rx(0.50618) ├──■───────┤ X ├─────»
# «      ├─────────────┤├─────────────┤├─────────────┤┌─┴─┐     └───┘     »
# «q2_3: ┤ Rx(0.23822) ├┤ Rz(0.66115) ├┤ Rx(0.50618) ├┤ X ├───────■───────»
# «      ├─────────────┤├─────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_4: ┤ Rx(0.23822) ├┤ Rz(0.66115) ├┤ Rx(0.50618) ├──■───────┤ X ├─────»
# «      ├─────────────┤├─────────────┤├─────────────┤┌─┴─┐     └───┘     »
# «q2_5: ┤ Rx(0.23822) ├┤ Rz(0.66115) ├┤ Rx(0.50618) ├┤ X ├───────■───────»
# «      ├─────────────┤├─────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_6: ┤ Rx(0.23822) ├┤ Rz(0.66115) ├┤ Rx(0.50618) ├──■───────┤ X ├─────»
# «      ├─────────────┤├─────────────┤├─────────────┤┌─┴─┐     └───┘     »
# «q2_7: ┤ Rx(0.23822) ├┤ Rz(0.66115) ├┤ Rx(0.50618) ├┤ X ├───────■───────»
# «      ├─────────────┤├─────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_8: ┤ Rx(0.23822) ├┤ Rz(0.66115) ├┤ Rx(0.50618) ├──■───────┤ X ├─────»
# «      ├─────────────┤├─────────────┤└─────────────┘┌─┴─┐┌────┴───┴────┐»
# «q2_9: ┤ Rz(0.66115) ├┤ Rx(0.50618) ├───────────────┤ X ├┤ Rx(0.54273) ├»
# «      └─────────────┘└─────────────┘               └───┘└─────────────┘»
# «      ┌──────────────┐┌─────────────┐                     ┌─────────────┐»
# «q2_0: ┤ Rz(0.017739) ├┤ Rx(0.73547) ├──────────────────■──┤ Rx(0.94634) ├»
# «      ├─────────────┬┘├─────────────┴┐┌─────────────┐┌─┴─┐└─────────────┘»
# «q2_1: ┤ Rx(0.54273) ├─┤ Rz(0.017739) ├┤ Rx(0.73547) ├┤ X ├───────■───────»
# «      ├─────────────┤ ├──────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_2: ┤ Rx(0.54273) ├─┤ Rz(0.017739) ├┤ Rx(0.73547) ├──■───────┤ X ├─────»
# «      ├─────────────┤ ├──────────────┤├─────────────┤┌─┴─┐     └───┘     »
# «q2_3: ┤ Rx(0.54273) ├─┤ Rz(0.017739) ├┤ Rx(0.73547) ├┤ X ├───────■───────»
# «      ├─────────────┤ ├──────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_4: ┤ Rx(0.54273) ├─┤ Rz(0.017739) ├┤ Rx(0.73547) ├──■───────┤ X ├─────»
# «      ├─────────────┤ ├──────────────┤├─────────────┤┌─┴─┐     └───┘     »
# «q2_5: ┤ Rx(0.54273) ├─┤ Rz(0.017739) ├┤ Rx(0.73547) ├┤ X ├───────■───────»
# «      ├─────────────┤ ├──────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_6: ┤ Rx(0.54273) ├─┤ Rz(0.017739) ├┤ Rx(0.73547) ├──■───────┤ X ├─────»
# «      ├─────────────┤ ├──────────────┤├─────────────┤┌─┴─┐     └───┘     »
# «q2_7: ┤ Rx(0.54273) ├─┤ Rz(0.017739) ├┤ Rx(0.73547) ├┤ X ├───────■───────»
# «      ├─────────────┤ ├──────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_8: ┤ Rx(0.54273) ├─┤ Rz(0.017739) ├┤ Rx(0.73547) ├──■───────┤ X ├─────»
# «      ├─────────────┴┐├─────────────┬┘└─────────────┘┌─┴─┐┌────┴───┴────┐»
# «q2_9: ┤ Rz(0.017739) ├┤ Rx(0.73547) ├────────────────┤ X ├┤ Rx(0.94634) ├»
# «      └──────────────┘└─────────────┘                └───┘└─────────────┘»
# «      ┌─────────────┐┌─────────────┐                    ┌─────────────┐»
# «q2_0: ┤ Rz(0.17484) ├┤ Rx(0.25616) ├─────────────────■──┤ Rx(0.45911) ├»
# «      ├─────────────┤├─────────────┤┌─────────────┐┌─┴─┐└─────────────┘»
# «q2_1: ┤ Rx(0.94634) ├┤ Rz(0.17484) ├┤ Rx(0.25616) ├┤ X ├───────■───────»
# «      ├─────────────┤├─────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_2: ┤ Rx(0.94634) ├┤ Rz(0.17484) ├┤ Rx(0.25616) ├──■───────┤ X ├─────»
# «      ├─────────────┤├─────────────┤├─────────────┤┌─┴─┐     └───┘     »
# «q2_3: ┤ Rx(0.94634) ├┤ Rz(0.17484) ├┤ Rx(0.25616) ├┤ X ├───────■───────»
# «      ├─────────────┤├─────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_4: ┤ Rx(0.94634) ├┤ Rz(0.17484) ├┤ Rx(0.25616) ├──■───────┤ X ├─────»
# «      ├─────────────┤├─────────────┤├─────────────┤┌─┴─┐     └───┘     »
# «q2_5: ┤ Rx(0.94634) ├┤ Rz(0.17484) ├┤ Rx(0.25616) ├┤ X ├───────■───────»
# «      ├─────────────┤├─────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_6: ┤ Rx(0.94634) ├┤ Rz(0.17484) ├┤ Rx(0.25616) ├──■───────┤ X ├─────»
# «      ├─────────────┤├─────────────┤├─────────────┤┌─┴─┐     └───┘     »
# «q2_7: ┤ Rx(0.94634) ├┤ Rz(0.17484) ├┤ Rx(0.25616) ├┤ X ├───────■───────»
# «      ├─────────────┤├─────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_8: ┤ Rx(0.94634) ├┤ Rz(0.17484) ├┤ Rx(0.25616) ├──■───────┤ X ├─────»
# «      ├─────────────┤├─────────────┤└─────────────┘┌─┴─┐┌────┴───┴────┐»
# «q2_9: ┤ Rz(0.17484) ├┤ Rx(0.25616) ├───────────────┤ X ├┤ Rx(0.45911) ├»
# «      └─────────────┘└─────────────┘               └───┘└─────────────┘»
# «      ┌─────────────┐┌─────────────┐                    ┌─────────────┐»
# «q2_0: ┤ Rz(0.21203) ├┤ Rx(0.63813) ├─────────────────■──┤ Rx(0.98194) ├»
# «      ├─────────────┤├─────────────┤┌─────────────┐┌─┴─┐└─────────────┘»
# «q2_1: ┤ Rx(0.45911) ├┤ Rz(0.21203) ├┤ Rx(0.63813) ├┤ X ├───────■───────»
# «      ├─────────────┤├─────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_2: ┤ Rx(0.45911) ├┤ Rz(0.21203) ├┤ Rx(0.63813) ├──■───────┤ X ├─────»
# «      ├─────────────┤├─────────────┤├─────────────┤┌─┴─┐     └───┘     »
# «q2_3: ┤ Rx(0.45911) ├┤ Rz(0.21203) ├┤ Rx(0.63813) ├┤ X ├───────■───────»
# «      ├─────────────┤├─────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_4: ┤ Rx(0.45911) ├┤ Rz(0.21203) ├┤ Rx(0.63813) ├──■───────┤ X ├─────»
# «      ├─────────────┤├─────────────┤├─────────────┤┌─┴─┐     └───┘     »
# «q2_5: ┤ Rx(0.45911) ├┤ Rz(0.21203) ├┤ Rx(0.63813) ├┤ X ├───────■───────»
# «      ├─────────────┤├─────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_6: ┤ Rx(0.45911) ├┤ Rz(0.21203) ├┤ Rx(0.63813) ├──■───────┤ X ├─────»
# «      ├─────────────┤├─────────────┤├─────────────┤┌─┴─┐     └───┘     »
# «q2_7: ┤ Rx(0.45911) ├┤ Rz(0.21203) ├┤ Rx(0.63813) ├┤ X ├───────■───────»
# «      ├─────────────┤├─────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_8: ┤ Rx(0.45911) ├┤ Rz(0.21203) ├┤ Rx(0.63813) ├──■───────┤ X ├─────»
# «      ├─────────────┤├─────────────┤└─────────────┘┌─┴─┐┌────┴───┴────┐»
# «q2_9: ┤ Rz(0.21203) ├┤ Rx(0.63813) ├───────────────┤ X ├┤ Rx(0.98194) ├»
# «      └─────────────┘└─────────────┘               └───┘└─────────────┘»
# «      ┌─────────────┐┌─────────────┐                    ┌─────────────┐»
# «q2_0: ┤ Rz(0.80418) ├┤ Rx(0.84024) ├─────────────────■──┤ Rx(0.20609) ├»
# «      ├─────────────┤├─────────────┤┌─────────────┐┌─┴─┐└─────────────┘»
# «q2_1: ┤ Rx(0.98194) ├┤ Rz(0.80418) ├┤ Rx(0.84024) ├┤ X ├───────■───────»
# «      ├─────────────┤├─────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_2: ┤ Rx(0.98194) ├┤ Rz(0.80418) ├┤ Rx(0.84024) ├──■───────┤ X ├─────»
# «      ├─────────────┤├─────────────┤├─────────────┤┌─┴─┐     └───┘     »
# «q2_3: ┤ Rx(0.98194) ├┤ Rz(0.80418) ├┤ Rx(0.84024) ├┤ X ├───────■───────»
# «      ├─────────────┤├─────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_4: ┤ Rx(0.98194) ├┤ Rz(0.80418) ├┤ Rx(0.84024) ├──■───────┤ X ├─────»
# «      ├─────────────┤├─────────────┤├─────────────┤┌─┴─┐     └───┘     »
# «q2_5: ┤ Rx(0.98194) ├┤ Rz(0.80418) ├┤ Rx(0.84024) ├┤ X ├───────■───────»
# «      ├─────────────┤├─────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_6: ┤ Rx(0.98194) ├┤ Rz(0.80418) ├┤ Rx(0.84024) ├──■───────┤ X ├─────»
# «      ├─────────────┤├─────────────┤├─────────────┤┌─┴─┐     └───┘     »
# «q2_7: ┤ Rx(0.98194) ├┤ Rz(0.80418) ├┤ Rx(0.84024) ├┤ X ├───────■───────»
# «      ├─────────────┤├─────────────┤├─────────────┤└───┘     ┌─┴─┐     »
# «q2_8: ┤ Rx(0.98194) ├┤ Rz(0.80418) ├┤ Rx(0.84024) ├──■───────┤ X ├─────»
# «      ├─────────────┤├─────────────┤└─────────────┘┌─┴─┐┌────┴───┴────┐»
# «q2_9: ┤ Rz(0.80418) ├┤ Rx(0.84024) ├───────────────┤ X ├┤ Rx(0.20609) ├»
# «      └─────────────┘└─────────────┘               └───┘└─────────────┘»
# «       ┌────────────┐┌─────────────┐                    ┌────────────┐»
# «q2_0: ─┤ Rz(0.7538) ├┤ Rx(0.46983) ├─────────────────■──┤ Rx(0.4721) ├»
# «      ┌┴────────────┤└┬────────────┤┌─────────────┐┌─┴─┐└────────────┘»
# «q2_1: ┤ Rx(0.20609) ├─┤ Rz(0.7538) ├┤ Rx(0.46983) ├┤ X ├──────■───────»
# «      ├─────────────┤ ├────────────┤├─────────────┤└───┘    ┌─┴─┐     »
# «q2_2: ┤ Rx(0.20609) ├─┤ Rz(0.7538) ├┤ Rx(0.46983) ├──■──────┤ X ├─────»
# «      ├─────────────┤ ├────────────┤├─────────────┤┌─┴─┐    └───┘     »
# «q2_3: ┤ Rx(0.20609) ├─┤ Rz(0.7538) ├┤ Rx(0.46983) ├┤ X ├──────■───────»
# «      ├─────────────┤ ├────────────┤├─────────────┤└───┘    ┌─┴─┐     »
# «q2_4: ┤ Rx(0.20609) ├─┤ Rz(0.7538) ├┤ Rx(0.46983) ├──■──────┤ X ├─────»
# «      ├─────────────┤ ├────────────┤├─────────────┤┌─┴─┐    └───┘     »
# «q2_5: ┤ Rx(0.20609) ├─┤ Rz(0.7538) ├┤ Rx(0.46983) ├┤ X ├──────■───────»
# «      ├─────────────┤ ├────────────┤├─────────────┤└───┘    ┌─┴─┐     »
# «q2_6: ┤ Rx(0.20609) ├─┤ Rz(0.7538) ├┤ Rx(0.46983) ├──■──────┤ X ├─────»
# «      ├─────────────┤ ├────────────┤├─────────────┤┌─┴─┐    └───┘     »
# «q2_7: ┤ Rx(0.20609) ├─┤ Rz(0.7538) ├┤ Rx(0.46983) ├┤ X ├──────■───────»
# «      ├─────────────┤ ├────────────┤├─────────────┤└───┘    ┌─┴─┐     »
# «q2_8: ┤ Rx(0.20609) ├─┤ Rz(0.7538) ├┤ Rx(0.46983) ├──■──────┤ X ├─────»
# «      └┬────────────┤┌┴────────────┤└─────────────┘┌─┴─┐┌───┴───┴────┐»
# «q2_9: ─┤ Rz(0.7538) ├┤ Rx(0.46983) ├───────────────┤ X ├┤ Rx(0.4721) ├»
# «       └────────────┘└─────────────┘               └───┘└────────────┘»
# «      ┌─────────────┐┌─────────────┐                    ┌────────────┐»
# «q2_0: ┤ Rz(0.82243) ├┤ Rx(0.30405) ├─────────────────■──┤ Rx(0.2218) ├»
# «      └┬────────────┤├─────────────┤┌─────────────┐┌─┴─┐└────────────┘»
# «q2_1: ─┤ Rx(0.4721) ├┤ Rz(0.82243) ├┤ Rx(0.30405) ├┤ X ├──────■───────»
# «       ├────────────┤├─────────────┤├─────────────┤└───┘    ┌─┴─┐     »
# «q2_2: ─┤ Rx(0.4721) ├┤ Rz(0.82243) ├┤ Rx(0.30405) ├──■──────┤ X ├─────»
# «       ├────────────┤├─────────────┤├─────────────┤┌─┴─┐    └───┘     »
# «q2_3: ─┤ Rx(0.4721) ├┤ Rz(0.82243) ├┤ Rx(0.30405) ├┤ X ├──────■───────»
# «       ├────────────┤├─────────────┤├─────────────┤└───┘    ┌─┴─┐     »
# «q2_4: ─┤ Rx(0.4721) ├┤ Rz(0.82243) ├┤ Rx(0.30405) ├──■──────┤ X ├─────»
# «       ├────────────┤├─────────────┤├─────────────┤┌─┴─┐    └───┘     »
# «q2_5: ─┤ Rx(0.4721) ├┤ Rz(0.82243) ├┤ Rx(0.30405) ├┤ X ├──────■───────»
# «       ├────────────┤├─────────────┤├─────────────┤└───┘    ┌─┴─┐     »
# «q2_6: ─┤ Rx(0.4721) ├┤ Rz(0.82243) ├┤ Rx(0.30405) ├──■──────┤ X ├─────»
# «       ├────────────┤├─────────────┤├─────────────┤┌─┴─┐    └───┘     »
# «q2_7: ─┤ Rx(0.4721) ├┤ Rz(0.82243) ├┤ Rx(0.30405) ├┤ X ├──────■───────»
# «       ├────────────┤├─────────────┤├─────────────┤└───┘    ┌─┴─┐     »
# «q2_8: ─┤ Rx(0.4721) ├┤ Rz(0.82243) ├┤ Rx(0.30405) ├──■──────┤ X ├─────»
# «      ┌┴────────────┤├─────────────┤└─────────────┘┌─┴─┐┌───┴───┴────┐»
# «q2_9: ┤ Rz(0.82243) ├┤ Rx(0.30405) ├───────────────┤ X ├┤ Rx(0.2218) ├»
# «      └─────────────┘└─────────────┘               └───┘└────────────┘»
# «      ┌─────────────┐┌─────────────┐
# «q2_0: ┤ Rz(0.23797) ├┤ Rx(0.90096) ├─────────────────■───────
# «      └┬────────────┤├─────────────┤┌─────────────┐┌─┴─┐
# «q2_1: ─┤ Rx(0.2218) ├┤ Rz(0.23797) ├┤ Rx(0.90096) ├┤ X ├──■──
# «       ├────────────┤├─────────────┤├─────────────┤└───┘┌─┴─┐
# «q2_2: ─┤ Rx(0.2218) ├┤ Rz(0.23797) ├┤ Rx(0.90096) ├──■──┤ X ├
# «       ├────────────┤├─────────────┤├─────────────┤┌─┴─┐└───┘
# «q2_3: ─┤ Rx(0.2218) ├┤ Rz(0.23797) ├┤ Rx(0.90096) ├┤ X ├──■──
# «       ├────────────┤├─────────────┤├─────────────┤└───┘┌─┴─┐
# «q2_4: ─┤ Rx(0.2218) ├┤ Rz(0.23797) ├┤ Rx(0.90096) ├──■──┤ X ├
# «       ├────────────┤├─────────────┤├─────────────┤┌─┴─┐└───┘
# «q2_5: ─┤ Rx(0.2218) ├┤ Rz(0.23797) ├┤ Rx(0.90096) ├┤ X ├──■──
# «       ├────────────┤├─────────────┤├─────────────┤└───┘┌─┴─┐
# «q2_6: ─┤ Rx(0.2218) ├┤ Rz(0.23797) ├┤ Rx(0.90096) ├──■──┤ X ├
# «       ├────────────┤├─────────────┤├─────────────┤┌─┴─┐└───┘
# «q2_7: ─┤ Rx(0.2218) ├┤ Rz(0.23797) ├┤ Rx(0.90096) ├┤ X ├──■──
# «       ├────────────┤├─────────────┤├─────────────┤└───┘┌─┴─┐
# «q2_8: ─┤ Rx(0.2218) ├┤ Rz(0.23797) ├┤ Rx(0.90096) ├──■──┤ X ├
# «      ┌┴────────────┤├─────────────┤└─────────────┘┌─┴─┐└───┘
# «q2_9: ┤ Rz(0.23797) ├┤ Rx(0.90096) ├───────────────┤ X ├─────
# «      └─────────────┘└─────────────┘               └───┘

# %%
#import FashionMNIST data
f = h5py.File('FashionMNIST_1_2_wk.mat','r')
x_train = f.get('x_train')
y_train = f.get('y_train')
x_test = f.get('x_test')
y_test = f.get('y_test')

x_train_array = np.array(x_train)
y_train_array = np.array(y_train)
x_test_array = np.array(x_test)
y_test_array = np.array(y_test)


#set size of training set, test set, scaling factor c = 2
num_qubit = 10
num_train = 500
num_test = 100
scaling_factor = 2
x_train = (x_train[:,1:num_train])
#for i in x_
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-6-96b6ee2a5cd6> in <module>
#       1 #import FashionMNIST data
# ----> 2 f = h5py.File('FashionMNIST_1_2_wk.mat','r')
#       3 x_train = f.get('x_train')
#       4 y_train = f.get('y_train')
#       5 x_test = f.get('x_test')
#
# ~/opt/anaconda3/lib/python3.8/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, **kwds)
#     422             with phil:
#     423                 fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0, **kwds)
# --> 424                 fid = make_fid(name, mode, userblock_size,
#     425                                fapl, fcpl=make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     426                                fs_persist=fs_persist, fs_threshold=fs_threshold),
#
# ~/opt/anaconda3/lib/python3.8/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     188         if swmr and swmr_support:
#     189             flags |= h5f.ACC_SWMR_READ
# --> 190         fid = h5f.open(name, flags, fapl=fapl)
#     191     elif mode == 'r+':
#     192         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = 'FashionMNIST_1_2_wk.mat', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
